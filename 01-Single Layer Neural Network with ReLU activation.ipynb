# %% [markdown]
# # Iris Dataset - Single Layer Neural Network with ReLU activation
# #### Prepared by Hansel Wei for 4010 Deep Learning w/ Tensorflow

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

RANDOM_SEED = 42
tf.set_random_seed(RANDOM_SEED)

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)
    
def reset_graph(seed=RANDOM_SEED):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %% [markdown]
# # Function to Load Iris Data

# %%
def get_iris_data():
    # load iris data
    iris   = datasets.load_iris()
    data   = iris["data"]
    target = iris["target"]

    # Prepend the column of 1s for bias
    N, M  = data.shape
    all_X = np.ones((N, M + 1))
    all_X[:, 1:] = data

    # Convert into one-hot vectors (converts categorical data to integer data)
    num_labels = len(np.unique(target))
    
    # Return a 2-D array with ones on the diagonal and zeros elsewhere.
    all_Y = np.eye(num_labels)[target]  
    return train_test_split(all_X, all_Y, test_size=0.33, random_state=RANDOM_SEED)

# %% [markdown]
# # Perceptron

# %%
import os  # imports the os
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(random_state=42, max_iter=1000)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])

# %%
a = -per_clf.coef_[0][0] / per_clf.coef_[0][1]
b = -per_clf.intercept_ / per_clf.coef_[0][1]

axes = [0, 5, 0, 2]

x0, x1 = np.meshgrid(
        np.linspace(axes[0], axes[1], 500).reshape(-1, 1),
        np.linspace(axes[2], axes[3], 200).reshape(-1, 1),
    ) # creates the meshgrid
X_new = np.c_[x0.ravel(), x1.ravel()]
y_predict = per_clf.predict(X_new)
zz = y_predict.reshape(x0.shape)

plt.figure(figsize=(10, 4))
plt.plot(X[y==0, 0], X[y==0, 1], "bs", label="Not Iris-Setosa")
plt.plot(X[y==1, 0], X[y==1, 1], "yo", label="Iris-Setosa")

plt.plot([axes[0], axes[1]], [a * axes[0] + b, a * axes[1] + b], "k-")
from matplotlib.colors import ListedColormap
custom_cmap = ListedColormap(['#9898ff', '#fafab0'])

plt.contourf(x0, x1, zz, cmap=custom_cmap)
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(loc="lower right", fontsize=14)
plt.axis(axes)

save_fig("perceptron_iris_plot")
plt.show()
# Out:
# Saving figure perceptron_iris_plot

# %% [markdown]
# # Function to create a neuron layer
# Unfortunately this has been deprecated due to getshape() not being a thing anymore so, moving on!

# %%
# def neuron_layer(X, n_neurons, name, activation=None):
#     with tf.name_scope(name):
#         # get the number of inputs by getting the input shape
#         n_inputs = int(tf.reshape(X.getshape()[1])
#         # getting size of second dimension
#         stdev = 2 / np.sqrt(n_inputs)
#         # 2D tensor connecting weights between each 
#         init = tf.truncated_normal((n_inputs, n_nerons))
#         # hold the weights (called the layer kernel)
#         W = tf.Variable(init, name="kernel")
#         # creates bias initalized to 0
#         b = tf.Variable(tf.zeros([n_neurons]), name="bias")
#         # weights of sums of the imputs plus the bias term for each and every neuron (Z = X * W + b) 
#         Z = tf.matmul(X, W) + b
        
#         if activation is not None:
#             return activation(Z)
#         else:
#             return Z

# %% [markdown]
# # Using dense() instead of neuron_layer()

# %%
# init ndarrays from data
train_X, test_X, train_y, test_y = get_iris_data()

# Layer's sizes
n_inputs = train_X.shape[1]   # Number of input nodes: 4 features and 1 bias
n_hidden1 = 256                # Number of hidden nodes
# n_hidden# able to create additonal layers here
# n_hidden2 = 100
n_outputs = train_y.shape[1]   # Number of outcomes (3 iris flowers)

# %%
reset_graph()

# Symbols
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")

# Create neuron layers
with tf.name_scope("dnn"):
#     hidden1 = neuron_layer(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1",
                              activation=tf.nn.relu)
# hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
# logits = neuron_layer(hidden2, n_outputs, name="outputs")
# logits = tf.layers.dense(hidden2, n_outputs, name="outputs")
    logits = tf.layers.dense(hidden1, n_outputs, name="outputs")
    print(logits)
# Out:
# Tensor("dnn/outputs/BiasAdd:0", shape=(?, 3), dtype=float32)

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
predict = tf.argmax(logits, axis=1)

# Backward propagation
cost    = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=logits))
updates = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %% [markdown]
# # Train model

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for epoch in range(100):
        # Train with each example
        for i in range(len(train_X)):
            sess.run(updates, feed_dict={X: train_X[i: i + 1], y: train_y[i: i + 1]})

        train_accuracy = np.mean(np.argmax(train_y, axis=1) ==
                                 sess.run(predict, feed_dict={X: train_X, y: train_y}))
        test_accuracy  = np.mean(np.argmax(test_y, axis=1) ==
                                 sess.run(predict, feed_dict={X: test_X, y: test_y}))

        print("Epoch = %d, train accuracy = %.2f%%, test accuracy = %.2f%%"
              % (epoch + 1, 100. * train_accuracy, 100. * test_accuracy))

sess.close()
# Out:
# Epoch = 1, train accuracy = 65.00%, test accuracy = 70.00%
# Epoch = 2, train accuracy = 69.00%, test accuracy = 72.00%
# Epoch = 3, train accuracy = 78.00%, test accuracy = 82.00%
# Epoch = 4, train accuracy = 84.00%, test accuracy = 86.00%
# Epoch = 5, train accuracy = 90.00%, test accuracy = 92.00%
# Epoch = 6, train accuracy = 92.00%, test accuracy = 94.00%
# Epoch = 7, train accuracy = 92.00%, test accuracy = 96.00%
# Epoch = 8, train accuracy = 93.00%, test accuracy = 98.00%
# Epoch = 9, train accuracy = 93.00%, test accuracy = 98.00%
# Epoch = 10, train accuracy = 94.00%, test accuracy = 98.00%
# Epoch = 11, train accuracy = 94.00%, test accuracy = 98.00%
# Epoch = 12, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 13, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 14, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 15, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 16, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 17, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 18, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 19, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 20, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 21, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 22, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 23, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 24, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 25, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 26, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 27, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 28, train accuracy = 96.00%, test accuracy = 98.00%
# Epoch = 29, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 30, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 31, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 32, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 33, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 34, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 35, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 36, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 37, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 38, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 39, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 40, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 41, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 42, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 43, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 44, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 45, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 46, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 47, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 48, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 49, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 50, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 51, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 52, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 53, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 54, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 55, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 56, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 57, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 58, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 59, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 60, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 61, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 62, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 63, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 64, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 65, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 66, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 67, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 68, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 69, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 70, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 71, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 72, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 73, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 74, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 75, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 76, train accuracy = 97.00%, test accuracy = 98.00%
# Epoch = 77, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 78, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 79, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 80, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 81, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 82, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 83, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 84, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 85, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 86, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 87, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 88, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 89, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 90, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 91, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 92, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 93, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 94, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 95, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 96, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 97, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 98, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 99, train accuracy = 98.00%, test accuracy = 98.00%
# Epoch = 100, train accuracy = 98.00%, test accuracy = 98.00%

# %% [markdown]
# # Full Experiment

# %%
import pandas as pd

# Experiment with layers 1 to 256
for hidden_layer in range(1,257):
    reset_graph()
    
    # init ndarrays from data
    train_X, test_X, train_y, test_y = get_iris_data()

    # Layer's sizes
    n_inputs = train_X.shape[1]   # Number of input nodes: 4 features and 1 bias
    n_hidden1 = hidden_layer       # Number of hidden nodes
    n_outputs = train_y.shape[1]   # Number of outcomes (3 iris flowers)

    # Symbols
    X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
    y = tf.placeholder(tf.int32, shape=(None), name="y")
    
    # Create neuron layers
    with tf.name_scope("dnn"):
        hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
        logits = tf.layers.dense(hidden1, n_outputs, name="outputs")
        print(logits)
        sess = tf.Session()
        init = tf.global_variables_initializer()
        sess.run(init)
    
    # loss
    with tf.name_scope("loss"):
        xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
        loss = tf.reduce_mean(xentropy, name="loss")
    
    # train
    learning_rate = 0.01

    with tf.name_scope("train"):
        optimizer = tf.train.GradientDescentOptimizer(learning_rate)
        training_op = optimizer.minimize(loss)
    
    # evaluate
    with tf.name_scope("eval"):
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()
    
    predict = tf.argmax(logits, axis=1)

    # Backward propagation
    cost    = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=logits))
    updates = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

    df = pd.DataFrame()
    
    for epoch in range(100):
            # Train with each example
            for i in range(len(train_X)):
                sess.run(updates, feed_dict={X: train_X[i: i + 1], y: train_y[i: i + 1]})

            train_accuracy = np.mean(np.argmax(train_y, axis=1) ==
                                     sess.run(predict, feed_dict={X: train_X, y: train_y}))
            test_accuracy  = np.mean(np.argmax(test_y, axis=1) ==
                                     sess.run(predict, feed_dict={X: test_X, y: test_y}))

            print("Hidden Layers = %d, Epoch = %d, train accuracy = %.2f%%, test accuracy = %.2f%%"
                  % (hidden_layer, epoch + 1, 100. * train_accuracy, 100. * test_accuracy))
    sess.close()
    print("="*100)
# Out:
# Tensor("dnn/outputs/BiasAdd:0", shape=(?, 3), dtype=float32)
# Hidden Layers = 1, Epoch = 1, train accuracy = 36.00%, test accuracy = 30.00%
# Hidden Layers = 1, Epoch = 2, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 1, Epoch = 3, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 1, Epoch = 4, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 1, Epoch = 5, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 1, Epoch = 6, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 1, Epoch = 7, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 8, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 9, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 10, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 11, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 12, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 13, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 14, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 15, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 16, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 17, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 18, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 19, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 20, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 21, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 22, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 23, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 24, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 25, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 26, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 27, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 28, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 29, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 30, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 31, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 32, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 33, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 34, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 35, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 36, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 37, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 38, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 39, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 40, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 41, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 42, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 43, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 44, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 45, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 46, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 47, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 48, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 49, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 50, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 51, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 52, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 53, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 54, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 55, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 56, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 57, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 58, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 59, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 60, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 61, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 62, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 63, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 64, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 65, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 66, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 67, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 68, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 69, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 70, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 71, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 72, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 73, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 74, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 75, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 76, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 77, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 78, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 79, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 80, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 81, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 82, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 83, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 84, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 85, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 86, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 87, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 88, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 89, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 90, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 91, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 92, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 93, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 94, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 95, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 96, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 97, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 98, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 99, train accuracy = 35.00%, test accuracy = 32.00%
# Hidden Layers = 1, Epoch = 100, train accuracy = 35.00%, test accuracy = 32.00%
# ====================================================================================================
# Tensor("dnn/outputs/BiasAdd:0", shape=(?, 3), dtype=float32)
# Hidden Layers = 2, Epoch = 1, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 2, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 3, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 4, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 5, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 6, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 7, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 8, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 9, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 10, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 11, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 12, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 13, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 14, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 15, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 16, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 17, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 18, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 19, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 20, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 21, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 22, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 23, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 24, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 25, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 26, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 27, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 28, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 29, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 30, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 31, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 32, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 33, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 34, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 35, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 36, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 37, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 38, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 39, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 40, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 41, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 42, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 43, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 44, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 45, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 46, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 47, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 48, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 49, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 50, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 51, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 52, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 53, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 54, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 55, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 56, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 57, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 58, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 59, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 60, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 61, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 62, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 63, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 64, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 65, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 66, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 67, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 68, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 69, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 70, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 71, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 72, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 73, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 74, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 75, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 76, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 77, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 78, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 79, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 80, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 81, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 82, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 83, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 84, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 85, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 86, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 87, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 88, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 89, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 90, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 91, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 92, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 93, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 94, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 95, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 96, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 97, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 98, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 99, train accuracy = 35.00%, test accuracy = 30.00%
# Hidden Layers = 2, Epoch = 100, train accuracy = 35.00%, test accuracy = 30.00%
# ====================================================================================================
# Tensor("dnn/outputs/BiasAdd:0", shape=(?, 3), dtype=float32)
# Hidden Layers = 3, Epoch = 1, train accuracy = 34.00%, test accuracy = 32.00%
# Hidden Layers = 3, Epoch = 2, train accuracy = 66.00%, test accuracy = 62.00%
# Hidden Layers = 3, Epoch = 3, train accuracy = 34.00%, test accuracy = 32.00%
# Hidden Layers = 3, Epoch = 4, train accuracy = 34.00%, test accuracy = 32.00%
# Hidden Layers = 3, Epoch = 5, train accuracy = 65.00%, test accuracy = 70.00%
# Hidden Layers = 3, Epoch = 6, train accuracy = 66.00%, test accuracy = 70.00%
# Hidden Layers = 3, Epoch = 7, train accuracy = 66.00%, test accuracy = 70.00%
# Hidden Layers = 3, Epoch = 8, train accuracy = 66.00%, test accuracy = 70.00%
# Hidden Layers = 3, Epoch = 9, train accuracy = 69.00%, test accuracy = 70.00%
# Hidden Layers = 3, Epoch = 10, train accuracy = 69.00%, test accuracy = 70.00%
# Hidden Layers = 3, Epoch = 11, train accuracy = 69.00%, test accuracy = 72.00%
# Hidden Layers = 3, Epoch = 12, train accuracy = 69.00%, test accuracy = 74.00%
# Hidden Layers = 3, Epoch = 13, train accuracy = 70.00%, test accuracy = 74.00%
# Hidden Layers = 3, Epoch = 14, train accuracy = 71.00%, test accuracy = 76.00%
# Hidden Layers = 3, Epoch = 15, train accuracy = 74.00%, test accuracy = 78.00%
# Hidden Layers = 3, Epoch = 16, train accuracy = 75.00%, test accuracy = 78.00%
# Hidden Layers = 3, Epoch = 17, train accuracy = 75.00%, test accuracy = 78.00%
# Hidden Layers = 3, Epoch = 18, train accuracy = 78.00%, test accuracy = 78.00%
# Hidden Layers = 3, Epoch = 19, train accuracy = 80.00%, test accuracy = 80.00%
# Hidden Layers = 3, Epoch = 20, train accuracy = 81.00%, test accuracy = 82.00%
# Hidden Layers = 3, Epoch = 21, train accuracy = 83.00%, test accuracy = 82.00%
# Hidden Layers = 3, Epoch = 22, train accuracy = 85.00%, test accuracy = 82.00%
# Hidden Layers = 3, Epoch = 23, train accuracy = 86.00%, test accuracy = 82.00%
# Hidden Layers = 3, Epoch = 24, train accuracy = 88.00%, test accuracy = 84.00%
# Hidden Layers = 3, Epoch = 25, train accuracy = 88.00%, test accuracy = 84.00%
# Hidden Layers = 3, Epoch = 26, train accuracy = 88.00%, test accuracy = 84.00%
# Hidden Layers = 3, Epoch = 27, train accuracy = 88.00%, test accuracy = 84.00%
# Hidden Layers = 3, Epoch = 28, train accuracy = 88.00%, test accuracy = 84.00%
# Hidden Layers = 3, Epoch = 29, train accuracy = 88.00%, test accuracy = 84.00%
# Hidden Layers = 3, Epoch = 30, train accuracy = 89.00%, test accuracy = 88.00%
# Hidden Layers = 3, Epoch = 31, train accuracy = 89.00%, test accuracy = 88.00%
# Hidden Layers = 3, Epoch = 32, train accuracy = 89.00%, test accuracy = 88.00%
# Hidden Layers = 3, Epoch = 33, train accuracy = 89.00%, test accuracy = 88.00%
# Hidden Layers = 3, Epoch = 34, train accuracy = 90.00%, test accuracy = 88.00%
# Hidden Layers = 3, Epoch = 35, train accuracy = 91.00%, test accuracy = 90.00%
# Hidden Layers = 3, Epoch = 36, train accuracy = 92.00%, test accuracy = 92.00%
# Hidden Layers = 3, Epoch = 37, train accuracy = 92.00%, test accuracy = 92.00%
# Hidden Layers = 3, Epoch = 38, train accuracy = 93.00%, test accuracy = 94.00%
# Hidden Layers = 3, Epoch = 39, train accuracy = 93.00%, test accuracy = 94.00%
# Hidden Layers = 3, Epoch = 40, train accuracy = 93.00%, test accuracy = 96.00%
# Hidden Layers = 3, Epoch = 41, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 42, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 43, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 44, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 45, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 46, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 47, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 48, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 49, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 50, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 51, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 52, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 53, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 54, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 55, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 56, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 57, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 58, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 59, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 60, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 61, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 62, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 63, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 64, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 65, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 66, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 67, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 68, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 69, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 70, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 71, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 72, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 73, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 74, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 75, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 76, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 77, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 78, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 79, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 80, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 81, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 82, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 83, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 84, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 85, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 86, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 87, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 88, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 89, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 90, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 91, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 92, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 93, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 94, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 95, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 96, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 97, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 98, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 99, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 3, Epoch = 100, train accuracy = 95.00%, test accuracy = 98.00%
# ====================================================================================================
# Tensor("dnn/outputs/BiasAdd:0", shape=(?, 3), dtype=float32)
# Hidden Layers = 4, Epoch = 1, train accuracy = 34.00%, test accuracy = 32.00%
# Hidden Layers = 4, Epoch = 2, train accuracy = 34.00%, test accuracy = 32.00%
# Hidden Layers = 4, Epoch = 3, train accuracy = 60.00%, test accuracy = 66.00%
# Hidden Layers = 4, Epoch = 4, train accuracy = 65.00%, test accuracy = 70.00%
# Hidden Layers = 4, Epoch = 5, train accuracy = 65.00%, test accuracy = 70.00%
# Hidden Layers = 4, Epoch = 6, train accuracy = 66.00%, test accuracy = 70.00%
# Hidden Layers = 4, Epoch = 7, train accuracy = 66.00%, test accuracy = 70.00%
# Hidden Layers = 4, Epoch = 8, train accuracy = 66.00%, test accuracy = 70.00%
# Hidden Layers = 4, Epoch = 9, train accuracy = 69.00%, test accuracy = 70.00%
# Hidden Layers = 4, Epoch = 10, train accuracy = 69.00%, test accuracy = 72.00%
# Hidden Layers = 4, Epoch = 11, train accuracy = 70.00%, test accuracy = 72.00%
# Hidden Layers = 4, Epoch = 12, train accuracy = 70.00%, test accuracy = 74.00%
# Hidden Layers = 4, Epoch = 13, train accuracy = 72.00%, test accuracy = 76.00%
# Hidden Layers = 4, Epoch = 14, train accuracy = 74.00%, test accuracy = 78.00%
# Hidden Layers = 4, Epoch = 15, train accuracy = 75.00%, test accuracy = 80.00%
# Hidden Layers = 4, Epoch = 16, train accuracy = 80.00%, test accuracy = 82.00%
# Hidden Layers = 4, Epoch = 17, train accuracy = 85.00%, test accuracy = 82.00%
# Hidden Layers = 4, Epoch = 18, train accuracy = 88.00%, test accuracy = 84.00%
# Hidden Layers = 4, Epoch = 19, train accuracy = 90.00%, test accuracy = 86.00%
# Hidden Layers = 4, Epoch = 20, train accuracy = 91.00%, test accuracy = 88.00%
# Hidden Layers = 4, Epoch = 21, train accuracy = 91.00%, test accuracy = 90.00%
# Hidden Layers = 4, Epoch = 22, train accuracy = 91.00%, test accuracy = 92.00%
# Hidden Layers = 4, Epoch = 23, train accuracy = 92.00%, test accuracy = 96.00%
# Hidden Layers = 4, Epoch = 24, train accuracy = 92.00%, test accuracy = 96.00%
# Hidden Layers = 4, Epoch = 25, train accuracy = 92.00%, test accuracy = 96.00%
# Hidden Layers = 4, Epoch = 26, train accuracy = 92.00%, test accuracy = 96.00%
# Hidden Layers = 4, Epoch = 27, train accuracy = 92.00%, test accuracy = 98.00%
# Hidden Layers = 4, Epoch = 28, train accuracy = 92.00%, test accuracy = 98.00%
# Hidden Layers = 4, Epoch = 29, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 4, Epoch = 30, train accuracy = 93.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 31, train accuracy = 93.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 32, train accuracy = 92.00%, test accuracy = 98.00%
# Hidden Layers = 4, Epoch = 33, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 4, Epoch = 34, train accuracy = 93.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 35, train accuracy = 93.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 36, train accuracy = 94.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 37, train accuracy = 94.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 38, train accuracy = 94.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 39, train accuracy = 95.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 40, train accuracy = 95.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 41, train accuracy = 95.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 42, train accuracy = 95.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 43, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 44, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 45, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 46, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 47, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 48, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 49, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 50, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 51, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 52, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 53, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 54, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 55, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 56, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 57, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 58, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 59, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 60, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 61, train accuracy = 96.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 62, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 63, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 64, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 65, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 66, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 67, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 68, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 69, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 70, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 71, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 72, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 73, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 74, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 75, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 76, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 77, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 78, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 79, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 80, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 81, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 82, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 83, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 84, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 85, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 86, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 87, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 88, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 89, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 90, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 91, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 92, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 93, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 94, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 95, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 96, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 97, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 98, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 99, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 4, Epoch = 100, train accuracy = 98.00%, test accuracy = 100.00%
# ====================================================================================================
# Tensor("dnn/outputs/BiasAdd:0", shape=(?, 3), dtype=float32)
# Hidden Layers = 5, Epoch = 1, train accuracy = 67.00%, test accuracy = 70.00%
# Hidden Layers = 5, Epoch = 2, train accuracy = 66.00%, test accuracy = 72.00%
# Hidden Layers = 5, Epoch = 3, train accuracy = 67.00%, test accuracy = 72.00%
# Hidden Layers = 5, Epoch = 4, train accuracy = 67.00%, test accuracy = 72.00%
# Hidden Layers = 5, Epoch = 5, train accuracy = 67.00%, test accuracy = 72.00%
# Hidden Layers = 5, Epoch = 6, train accuracy = 67.00%, test accuracy = 72.00%
# Hidden Layers = 5, Epoch = 7, train accuracy = 68.00%, test accuracy = 74.00%
# Hidden Layers = 5, Epoch = 8, train accuracy = 68.00%, test accuracy = 74.00%
# Hidden Layers = 5, Epoch = 9, train accuracy = 68.00%, test accuracy = 74.00%
# Hidden Layers = 5, Epoch = 10, train accuracy = 68.00%, test accuracy = 74.00%
# Hidden Layers = 5, Epoch = 11, train accuracy = 70.00%, test accuracy = 74.00%
# Hidden Layers = 5, Epoch = 12, train accuracy = 73.00%, test accuracy = 80.00%
# Hidden Layers = 5, Epoch = 13, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 14, train accuracy = 95.00%, test accuracy = 92.00%
# Hidden Layers = 5, Epoch = 15, train accuracy = 91.00%, test accuracy = 88.00%
# Hidden Layers = 5, Epoch = 16, train accuracy = 96.00%, test accuracy = 90.00%
# Hidden Layers = 5, Epoch = 17, train accuracy = 96.00%, test accuracy = 90.00%
# Hidden Layers = 5, Epoch = 18, train accuracy = 96.00%, test accuracy = 90.00%
# Hidden Layers = 5, Epoch = 19, train accuracy = 96.00%, test accuracy = 90.00%
# Hidden Layers = 5, Epoch = 20, train accuracy = 97.00%, test accuracy = 90.00%
# Hidden Layers = 5, Epoch = 21, train accuracy = 97.00%, test accuracy = 90.00%
# Hidden Layers = 5, Epoch = 22, train accuracy = 94.00%, test accuracy = 90.00%
# Hidden Layers = 5, Epoch = 23, train accuracy = 97.00%, test accuracy = 96.00%
# Hidden Layers = 5, Epoch = 24, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 25, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 26, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 27, train accuracy = 97.00%, test accuracy = 96.00%
# Hidden Layers = 5, Epoch = 28, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 29, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 30, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 31, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 32, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 33, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 34, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 35, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 36, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 37, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 38, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 39, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 40, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 41, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 42, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 43, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 44, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 45, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 46, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 47, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 48, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 49, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 50, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 51, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 52, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 53, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 54, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 55, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 56, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 57, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 58, train accuracy = 98.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 59, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 60, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 61, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 62, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 63, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 64, train accuracy = 97.00%, test accuracy = 100.00%
# Hidden Layers = 5, Epoch = 65, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 66, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 67, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 68, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 69, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 70, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 71, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 72, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 73, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 74, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 75, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 76, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 77, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 78, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 79, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 80, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 81, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 82, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 83, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 84, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 85, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 86, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 87, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 88, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 89, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 90, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 91, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 92, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 93, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 94, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 95, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 96, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 97, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 98, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 99, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 5, Epoch = 100, train accuracy = 97.00%, test accuracy = 98.00%
# ====================================================================================================
# Tensor("dnn/outputs/BiasAdd:0", shape=(?, 3), dtype=float32)
# Hidden Layers = 6, Epoch = 1, train accuracy = 65.00%, test accuracy = 70.00%
# Hidden Layers = 6, Epoch = 2, train accuracy = 65.00%, test accuracy = 70.00%
# Hidden Layers = 6, Epoch = 3, train accuracy = 66.00%, test accuracy = 70.00%
# Hidden Layers = 6, Epoch = 4, train accuracy = 69.00%, test accuracy = 72.00%
# Hidden Layers = 6, Epoch = 5, train accuracy = 80.00%, test accuracy = 84.00%
# Hidden Layers = 6, Epoch = 6, train accuracy = 83.00%, test accuracy = 90.00%
# Hidden Layers = 6, Epoch = 7, train accuracy = 89.00%, test accuracy = 92.00%
# Hidden Layers = 6, Epoch = 8, train accuracy = 91.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 9, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 10, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 11, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 12, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 13, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 14, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 15, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 16, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 17, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 18, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 19, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 20, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 21, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 22, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 23, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 24, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 25, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 26, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 27, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 28, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 29, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 30, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 31, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 32, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 33, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 34, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 35, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 36, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 37, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 38, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 39, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 40, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 41, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 42, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 43, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 44, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 45, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 46, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 47, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 48, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 49, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 50, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 51, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 52, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 53, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 54, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 55, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 56, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 57, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 58, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 59, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 60, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 61, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 62, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 63, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 64, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 65, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 66, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 67, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 68, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 69, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 70, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 71, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 72, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 73, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 74, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 75, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 76, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 77, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 78, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 79, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 80, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 81, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 82, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 83, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 84, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 85, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 86, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 87, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 88, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 89, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 90, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 91, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 92, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 93, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 94, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 95, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 6, Epoch = 96, train accuracy = 98.00%, test accuracy = 98.00%
# ...
# Hidden Layers = 255, Epoch = 7, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 8, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 9, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 10, train accuracy = 95.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 11, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 12, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 13, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 14, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 15, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 16, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 17, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 18, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 19, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 20, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 21, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 22, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 23, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 24, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 25, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 26, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 27, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 28, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 29, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 30, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 31, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 32, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 33, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 34, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 35, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 36, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 37, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 38, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 39, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 40, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 41, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 42, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 43, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 44, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 45, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 46, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 47, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 48, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 49, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 50, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 51, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 52, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 53, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 54, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 55, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 56, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 57, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 58, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 59, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 60, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 61, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 62, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 63, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 64, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 65, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 66, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 67, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 68, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 69, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 70, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 71, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 72, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 73, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 74, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 75, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 76, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 77, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 78, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 79, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 80, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 81, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 82, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 83, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 84, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 85, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 86, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 87, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 88, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 89, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 90, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 91, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 92, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 93, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 94, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 95, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 96, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 97, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 98, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 99, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 255, Epoch = 100, train accuracy = 98.00%, test accuracy = 98.00%
# ====================================================================================================
# Tensor("dnn/outputs/BiasAdd:0", shape=(?, 3), dtype=float32)
# Hidden Layers = 256, Epoch = 1, train accuracy = 65.00%, test accuracy = 70.00%
# Hidden Layers = 256, Epoch = 2, train accuracy = 69.00%, test accuracy = 72.00%
# Hidden Layers = 256, Epoch = 3, train accuracy = 78.00%, test accuracy = 82.00%
# Hidden Layers = 256, Epoch = 4, train accuracy = 84.00%, test accuracy = 86.00%
# Hidden Layers = 256, Epoch = 5, train accuracy = 90.00%, test accuracy = 92.00%
# Hidden Layers = 256, Epoch = 6, train accuracy = 92.00%, test accuracy = 94.00%
# Hidden Layers = 256, Epoch = 7, train accuracy = 92.00%, test accuracy = 96.00%
# Hidden Layers = 256, Epoch = 8, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 9, train accuracy = 93.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 10, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 11, train accuracy = 94.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 12, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 13, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 14, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 15, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 16, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 17, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 18, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 19, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 20, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 21, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 22, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 23, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 24, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 25, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 26, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 27, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 28, train accuracy = 96.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 29, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 30, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 31, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 32, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 33, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 34, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 35, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 36, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 37, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 38, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 39, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 40, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 41, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 42, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 43, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 44, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 45, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 46, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 47, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 48, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 49, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 50, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 51, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 52, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 53, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 54, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 55, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 56, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 57, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 58, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 59, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 60, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 61, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 62, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 63, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 64, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 65, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 66, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 67, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 68, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 69, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 70, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 71, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 72, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 73, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 74, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 75, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 76, train accuracy = 97.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 77, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 78, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 79, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 80, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 81, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 82, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 83, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 84, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 85, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 86, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 87, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 88, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 89, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 90, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 91, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 92, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 93, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 94, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 95, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 96, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 97, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 98, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 99, train accuracy = 98.00%, test accuracy = 98.00%
# Hidden Layers = 256, Epoch = 100, train accuracy = 98.00%, test accuracy = 98.00%
# ====================================================================================================
